# %%
import numpy as np
from juliacall import Main as jl
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
jl.seval("import Pkg; Pkg.add(url=\"git@github.com:MPF-Optimization-Laboratory/KLLS.jl.git\")")
# Out:
#      Cloning git-repo `git@github.com:MPF-Optimization-Laboratory/KLLS.jl.git`
#     Updating git-repo `git@github.com:MPF-Optimization-Laboratory/KLLS.jl.git`
#    Resolving package versions...
#    Installed PlotThemes ──────── v3.2.0
#    Installed MPItrampoline_jll ─ v5.4.0+0
#    Installed TimerOutputs ────── v0.5.24
#    Installed PrettyTables ────── v2.3.2
#    Installed JSOSolvers ──────── v0.12.0
#    Installed NLPModels ───────── v0.21.1
#    Installed SolverTools ─────── v0.9.0
#    Installed MAT ─────────────── v0.10.7
#     Updating `~/Documents/projects/Software/KLLS/.venv/julia_env/Project.toml`
#   [a1edf54d] + KLLS v1.0.0-DEV `git@github.com:MPF-Optimization-Laboratory/KLLS.jl.git#main`
#     Updating `~/Documents/projects/Software/KLLS/.venv/julia_env/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.0.4
#   [66dad0bd] + AliasTables v1.1.3
#   [7d9fca2a] + Arpack v0.5.4
#   [13072b0f] + AxisAlgorithms v1.1.0
# ...

# %%
jl.seval("using KLLS")

# %%
A = np.random.rand(2,3)
b =  
jl.KLLSData(matrix = np.random.rand(2, 3), [3., 4.]]), np.array([1., 2.]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 jl.KLLSData(np.array([[1., 2.], [3., 4.]]), np.array([1., 2.]))
#
# File ~/.julia/packages/PythonCall/S5MOg/src/JlWrap/any.jl:223, in __call__(self, *args, **kwargs)
#     221     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     222 def __call__(self, *args, **kwargs):
# --> 223     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     224 def __bool__(self):
#     225     return True
#
# TypeError: Julia: MethodError: no method matching KLLSData(::PyArray{Float64, 2, true, false, Float64}, ::PyArray{Float64, 1, true, true, Float64}, ::Vector{Float64}, ::KLLS.LogExpFunction{Vector{Float64}}, ::Float64, ::Vector{Float64}, ::Float64, ::String)
#
# Closest candidates are:
# ...

# %%
jl.array([1., 2.])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 jl.array([1., 2.])
#
# File ~/.julia/packages/PythonCall/S5MOg/src/JlWrap/any.jl:210, in __getattr__(self, k)
#     208         raise AttributeError(k)
#     209     else:
# --> 210         return self._jl_callmethod($(pyjl_methodnum(pyjlany_getattr)), k)
#     211 def __setattr__(self, k, v):
#     212     try:
#
# AttributeError: Julia: UndefVarError: `array` not defined

# %%
matrix = np.random.rand(2, 3)
print(matrix)
# Out:
# [[0.4039698  0.3577691  0.57338633]
#  [0.91280425 0.95434843 0.17260071]]
